# %%
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import pandas as pd
import os
import numpy as np

# %%
num_classes = 12
csv_path = "./class.csv"

# %%
model = models.inception_v3(pretrained=True) #凍結權重
'''for param in model.parameters():
    param.requires_grad = False'''
# Out:
# 'for param in model.parameters():\n    param.requires_grad = False'

# %%
# 替換 Inception-v3 的最後全連接層
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
model.train()
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=12, bias=True)
# )

# %%
# Inception-v3 模型需要特定的影像輸入格式（299x299 像素，RGB 圖像，並且需要正規化）。使用 torchvision.transforms 進行預處理。
preprocess = transforms.Compose([
    transforms.Resize(299),
    transforms.CenterCrop(299),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class train_loader():
    
    def __init__(self,path):
        self.imgs=[]
        self.labels=[]
        df = pd.read_csv(path)
        for index, row in df.iterrows():
            image_path = row['path']
            label = row['label']

            if os.path.exists(image_path):
                img = Image.open(image_path)
                img_tensor = preprocess(img)
                self.imgs.append(img_tensor)
                self.labels.append(label)
                #img.show()

                # image processing
                print(f"\rloading image: {image_path} with label: {label}")
            else:
                print(f"Image not found: {image_path}\n")

        self.labels = torch.tensor(self.labels)
        self.criterion = torch.nn.CrossEntropyLoss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
data_set=train_loader(csv_path)
# Out:
# loading image: ./Dataset/alcohol_tissue/IMG_2555.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2556.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2557.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2558.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2559.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2560.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2561.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2562.JPG with label: 0
# loading image: ./Dataset/alcohol_tissue/IMG_2563.JPG with label: 0
# loading image: ./Dataset/biscoff/IMG_2755.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2756.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2757.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2758.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2759.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2760.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2761.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2762.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2763.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2764.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2765.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2766.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2767.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2768.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2769.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2770.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2771.jpg with label: 1
# loading image: ./Dataset/biscoff/IMG_2772.jpg with label: 1
# loading image: ./Dataset/butter_cheese/IMG_2640.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2641.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2642.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2643.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2644.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2645.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2646.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2647.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2648.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2649.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2650.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2651.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2652.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2653.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2654.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2655.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2656.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2657.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2658.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2659.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2660.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2661.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2662.jpg with label: 2
# loading image: ./Dataset/butter_cheese/IMG_2663.jpg with label: 2
# loading image: ./Dataset/cadina/IMG_2516.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2517.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2518.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2519.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2520.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2521.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2522.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2524.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2525.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2526.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2527.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2528.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2529.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2530.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2531.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2532.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2533.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2534.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2535.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2536.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2537.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2538.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2539.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2540.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2541.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2542.JPG with label: 3
# loading image: ./Dataset/cadina/IMG_2543.JPG with label: 3
# loading image: ./Dataset/crispiroll/IMG_2687.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2688.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2689.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2690.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2691.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2692.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2693.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2694.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2695.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2696.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2697.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2698.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2699.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2700.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2701.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2702.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2703.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2704.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2705.jpg with label: 4
# loading image: ./Dataset/crispiroll/IMG_2706.jpg with label: 4
# loading image: ./Dataset/facewash/IMG_2544.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2545.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2546.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2547.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2548.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2549.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2550.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2551.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2552.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2553.JPG with label: 5
# loading image: ./Dataset/facewash/IMG_2554.JPG with label: 5
# loading image: ./Dataset/hokkaido/IMG_2664.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2665.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2666.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2667.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2668.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2669.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2670.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2671.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2672.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2673.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2674.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2675.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2676.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2677.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2678.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2679.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2680.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2681.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2682.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2683.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2684.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2685.jpg with label: 6
# loading image: ./Dataset/hokkaido/IMG_2686.jpg with label: 6
# loading image: ./Dataset/nothing/IMG_2596.JPG with label: 7
# loading image: ./Dataset/nothing/IMG_2707.jpg with label: 7
# loading image: ./Dataset/nothing/IMG_2708.jpg with label: 7
# loading image: ./Dataset/nothing/IMG_2709.jpg with label: 7
# loading image: ./Dataset/nothing/IMG_2710.jpg with label: 7
# loading image: ./Dataset/onion/IMG_2597.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2598.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2599.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2600.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2601.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2602.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2603.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2604.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2605.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2606.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2607.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2608.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2609.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2610.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2611.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2612.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2613.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2614.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2615.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2616.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2617.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2618.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2619.JPG with label: 8
# loading image: ./Dataset/onion/IMG_2620.JPG with label: 8
# loading image: ./Dataset/scientist_noodles/IMG_2712.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2713.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2714.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2715.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2716.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2717.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2718.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2719.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2720.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2721.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2722.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2723.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2724.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2725.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2726.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2727.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2728.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2729.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2730.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2731.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2732.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2733.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2734.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2735.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2736.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2737.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2738.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2739.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2740.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2741.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2742.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2743.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2744.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2745.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2746.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2747.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2748.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2749.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2750.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2751.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2752.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2753.jpg with label: 9
# loading image: ./Dataset/scientist_noodles/IMG_2754.jpg with label: 9
# loading image: ./Dataset/snapu_cookies/IMG_2773.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2774.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2775.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2776.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2777.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2778.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2779.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2780.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2781.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2782.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2783.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2784.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2785.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2786.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2787.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2788.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2789.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2790.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2791.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2792.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2793.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2794.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2795.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2796.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2797.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2798.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2799.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2800.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2801.jpg with label: 10
# loading image: ./Dataset/snapu_cookies/IMG_2802.jpg with label: 10
# loading image: ./Dataset/soda/IMG_2575.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2576.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2577.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2578.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2579.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2580.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2581.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2582.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2583.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2584.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2586.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2587.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2588.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2589.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2590.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2591.jpg with label: 11
# loading image: ./Dataset/soda/IMG_2592.JPG with label: 11
# loading image: ./Dataset/soda/IMG_2593.JPG with label: 11
# loading image: ./Dataset/soda/IMG_2594.JPG with label: 11
# loading image: ./Dataset/soda/IMG_2595.JPG with label: 11

# %%
model.train()
for epoch in range(num_classes):  # 訓練 10 個 epoch
    print(f"epoch: {epoch}\n")
    for (images, labels) in zip(data_set.imgs,data_set.labels):  # 迭代訓練數據
        labels = torch.tensor([labels])  # 確保 labels 是正確的維度
        images = images.unsqueeze(0)
        data_set.optimizer.zero_grad()

        model.eval()  # 關閉輔助分類器的輸出


        # 進行推理時返回兩個輸出
        outputs = model(images)

        loss = data_set.criterion(outputs, labels)

        loss.backward()

        data_set.optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 16
#      12 outputs = model(images)
#      14 loss = data_set.criterion(outputs, labels)
# ---> 16 loss.backward()
#      18 data_set.optimizer.step()
#
# File c:\tools\miniconda3\lib\site-packages\torch\_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File c:\tools\miniconda3\lib\site-packages\torch\autograd\__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File c:\tools\miniconda3\lib\site-packages\torch\autograd\graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:
